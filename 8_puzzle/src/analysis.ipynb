# %% [markdown]
# # Analysis

# %%
from game import Game

# %%
g = Game(random_grid=False, watch_moves=False, output=False)

# %%
# %timeit g.start()
# Out:
#  SOLUTION FOUND
#
# - Total iterations: 474
# - Total moves: 72
#
#
#  SOLUTION FOUND
#
# - Total iterations: 474
# - Total moves: 72
#
#
#  SOLUTION FOUND
#
# - Total iterations: 474
# - Total moves: 72
#
#
#  SOLUTION FOUND
#
# - Total iterations: 474
# - Total moves: 72
#
#
#  SOLUTION FOUND
#
# - Total iterations: 474
# - Total moves: 72
#
#
#  SOLUTION FOUND
#
# - Total iterations: 474
# - Total moves: 72
#
#
#  SOLUTION FOUND
#
# - Total iterations: 474
# - Total moves: 72
#
#
#  SOLUTION FOUND
#
# - Total iterations: 474
# - Total moves: 72
#
#
#  SOLUTION FOUND
#
# - Total iterations: 474
# - Total moves: 72
#
#
#  SOLUTION FOUND
#
# - Total iterations: 474
# - Total moves: 72
#
#
#  SOLUTION FOUND
#
# - Total iterations: 474
# - Total moves: 72
#
#
#  SOLUTION FOUND
#
# - Total iterations: 474
# - Total moves: 72
#
#
#  SOLUTION FOUND
#
# - Total iterations: 474
# - Total moves: 72
#
#
#  SOLUTION FOUND
#
# - Total iterations: 474
# - Total moves: 72
#
#
#  SOLUTION FOUND
#
# ...
